# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from xgboost import XGBRegressor
from sklearn.multioutput import MultiOutputRegressor
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Importing Datasets

# %%
df = pd.read_csv("Albedo_Map.csv", header = None) # Lunar Albedo Map
fe = pd.read_csv("LPFe_Map.csv", header = None) # Fe(Iron) Map
k = pd.read_csv("LPK_Map.csv", header = None)   # K(Potassium) Map
th = pd.read_csv("LPTh_Map.csv", header = None) # Th(Thorium) Map
ti = pd.read_csv("LPTi_Map.csv", header = None) # Ti(Titanium) Map

# %%
# Left half for training
x = df.iloc[:, 0:360].values
# Right half for prediction
y = df.iloc[:, 360:720].values

# %% [markdown]
# # Predicting using Iron(Fe) Dataset

# %%
#Spliting the image in two halves
fe_left = fe.iloc[:, 0:360].values
fe_right = fe.iloc[:, 360:720].values

# %%
regressor = MultiOutputRegressor(XGBRegressor(objective = 'reg:squarederror',n_estimators=100, random_state = 0))
regressor.fit(fe_left, x)
# Predicting the results
y_pred = regressor.predict(fe_right)

# %%
#comparing prediction with true value.
mean_squared_error(y,y_pred)
# Out:
# 0.002069264909468214

# %% [markdown]
# ## Output: Predicted Images Comparison

# %%
plt.figure(figsize =(10,10))
plt.subplot(1, 2, 1)
plt.imshow(x)
plt.title('Lunar Albedo Map (Left Half)', fontweight="bold")
plt.colorbar(orientation='horizontal', ticks=[])

plt.subplot(1, 2, 2)
plt.imshow(fe_left)
plt.title('Fe Lunar Map (Left Half)', fontweight="bold")
plt.colorbar(orientation='horizontal', label= 'Fe \n (Low to High)')

plt.figure(figsize =(20,20))
plt.subplot(1, 3, 1)
plt.imshow(y)
plt.colorbar(orientation='horizontal', ticks=[])
plt.title('Lunar Albedo Map (Right Half)', fontweight="bold")

plt.subplot(1, 3, 2)
plt.imshow(fe_right)
plt.colorbar(orientation='horizontal', label= 'Fe \n (Low to High)')
plt.title('Fe Lunar Map (Right Half)', fontweight="bold")

# plt.figure(figsize =(10,10))
plt.subplot(1, 3, 3)
plt.imshow(y_pred)
plt.colorbar(orientation='horizontal', ticks=[])
plt.title('Predicted Lunar Albedo Map (Right Half)', fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Predicted Lunar Albedo Map (Right Half)')

# %% [markdown]
# # Predicting using Potassium(K) Dataset

# %%
# Spliting the image in two halves
k_left = k.iloc[:, 0:360].values
k_right = k.iloc[:, 360:720].values

# %%
regressor = MultiOutputRegressor(XGBRegressor(objective = 'reg:squarederror',n_estimators=100, random_state = 0))
regressor.fit(k_left, x)
# Predicting the results
y_pred = regressor.predict(k_right)

# %% [markdown]
# ### Accuracy

# %%
#comparing prediction with true value.
mean_squared_error(y,y_pred)
# Out:
# 0.002228280587552275

# %% [markdown]
# ## Output: Predicted Images Comparison

# %%
plt.figure(figsize =(10,10))
plt.subplot(1, 2, 1)
plt.imshow(x)
plt.title('Lunar Albedo Map (Left Half)', fontweight="bold")
plt.colorbar(orientation='horizontal', ticks=[])

plt.subplot(1, 2, 2)
plt.imshow(k_left)
plt.title('K Lunar Map (Left Half)', fontweight="bold")
plt.colorbar(orientation='horizontal', label= 'K \n (Low to High)')

plt.figure(figsize =(20, 20))
plt.subplot(1, 3, 1)
plt.imshow(y)
plt.colorbar(orientation='horizontal', ticks=[])
plt.title('Lunar Albedo Map (Right Half)', fontweight="bold")

plt.subplot(1, 3, 2)
plt.imshow(k_right)
plt.title('K Lunar Map (Right Half)', fontweight="bold")
plt.colorbar(orientation='horizontal', label= 'K \n (Low to High)')

plt.subplot(1, 3, 3)
plt.imshow(y_pred)
plt.colorbar(orientation='horizontal', ticks=[])
plt.title('Predicted Image Lunar Albedo Map(Right Half)', fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Predicted Image Lunar Albedo Map(Right Half)')

# %% [markdown]
# # Predicting using Thorium(Th) Dataset

# %%
# Spliting the image in two halves
th_left = th.iloc[:, 0:360].values
th_right = th.iloc[:, 360:720].values

# %%
regressor = MultiOutputRegressor(XGBRegressor(objective = 'reg:squarederror',n_estimators=100, random_state = 0))
regressor.fit(th_left, x)
# Predicting the results
y_pred = regressor.predict(th_right)

# %% [markdown]
# ### Accuracy

# %%
#comparing prediction with true value.
mean_squared_error(y,y_pred)
# Out:
# 0.0024308096805426794

# %% [markdown]
# ### Output: Predicted Images Comparison

# %%
plt.figure(figsize =(10,10))
plt.subplot(1, 2, 1)
plt.imshow(x)
plt.title('Lunar Albedo Map (Left Half)', fontweight="bold")
plt.colorbar(orientation='horizontal', ticks=[])

plt.subplot(1, 2, 2)
plt.imshow(th_left)
plt.title('Th Lunar Map (Left Half)', fontweight="bold")
plt.colorbar(orientation='horizontal', label= 'Th \n (Low to High)')

plt.figure(figsize =(20,20))
plt.subplot(1, 3, 1)
plt.imshow(y)
plt.colorbar(orientation='horizontal', ticks=[])
plt.title('Lunar Albedo Map (Right Half)', fontweight="bold")

plt.subplot(1, 3, 2)
plt.imshow(th_right)
plt.title('Th Lunar Map (Right Half)', fontweight="bold")
plt.colorbar(orientation='horizontal', label= 'Th \n (Low to High)')

plt.subplot(1, 3, 3)
plt.imshow(y_pred)
plt.colorbar(orientation='horizontal', ticks=[])
plt.title('Predicted Image Lunar Albedo Map (Right Half)', fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Predicted Image Lunar Albedo Map (Right Half)')

# %% [markdown]
# # Predicting using Titanium (Ti) Dataset

# %%
# Spliting the image in two halves
ti_left = ti.iloc[:, 0:360].values
ti_right = ti.iloc[:, 360:720].values

# %%
regressor = MultiOutputRegressor(XGBRegressor(objective = 'reg:squarederror',n_estimators=100, random_state = 0))
regressor.fit(ti_left, x)
# Predicting the results
y_pred = regressor.predict(ti_right)

# %% [markdown]
# ### Accuracy

# %%
#comparing prediction with true value.
mean_squared_error(y,y_pred)
# Out:
# 0.001828789156679207

# %% [markdown]
# ### Output: Predicted Images Comparison

# %%
plt.figure(figsize =(10,10))
plt.subplot(1, 2, 1)
plt.imshow(x)
plt.title('Lunar Albedo Map (Left Half)', fontweight="bold")
plt.colorbar(orientation='horizontal', ticks=[])

plt.subplot(1, 2, 2)
plt.imshow(ti_left)
plt.title('Ti Lunar Map (Left Half)', fontweight="bold")
plt.colorbar(orientation='horizontal', label= 'Ti \n (Low to High)')

plt.figure(figsize =(20,20))
plt.subplot(1, 3, 1)
plt.imshow(y)
plt.colorbar(orientation='horizontal', ticks=[])
plt.title('Lunar Albedo Map (Right Half)', fontweight="bold")

plt.subplot(1, 3, 2)
plt.imshow(ti_right)
plt.title('Ti Lunar Map (Right Half)', fontweight="bold")
plt.colorbar(orientation='horizontal', label= 'Ti \n (Low to High)')

plt.subplot(1, 3, 3)
plt.imshow(y_pred)
plt.colorbar(orientation='horizontal', ticks=[])
plt.title('Predicted Image Lunar Albedo (Right Half)', fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Predicted Image Lunar Albedo (Right Half)')
